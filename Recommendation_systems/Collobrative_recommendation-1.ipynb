# %%
import pandas as pd
from surprise import Reader,Dataset,KNNWithMeans,accuracy
from surprise.model_selection import train_test_split

# %%
data_set=Dataset.load_builtin('ml-100k')
data_set.raw_ratings
# Out:
# [('196', '242', 3.0, '881250949'),
#  ('186', '302', 3.0, '891717742'),
#  ('22', '377', 1.0, '878887116'),
#  ('244', '51', 2.0, '880606923'),
#  ('166', '346', 1.0, '886397596'),
#  ('298', '474', 4.0, '884182806'),
#  ('115', '265', 2.0, '881171488'),
#  ('253', '465', 5.0, '891628467'),
#  ('305', '451', 3.0, '886324817'),
#  ('6', '86', 3.0, '883603013'),
#  ('62', '257', 2.0, '879372434'),
#  ('286', '1014', 5.0, '879781125'),
#  ('200', '222', 5.0, '876042340'),
#  ('210', '40', 3.0, '891035994'),
#  ('224', '29', 3.0, '888104457'),
#  ('303', '785', 3.0, '879485318'),
#  ('122', '387', 5.0, '879270459'),
#  ('194', '274', 2.0, '879539794'),
#  ('291', '1042', 4.0, '874834944'),
#  ('234', '1184', 2.0, '892079237'),
#  ('119', '392', 4.0, '886176814'),
#  ('167', '486', 4.0, '892738452'),
#  ('299', '144', 4.0, '877881320'),
#  ('291', '118', 2.0, '874833878'),
#  ('308', '1', 4.0, '887736532'),
#  ('95', '546', 2.0, '879196566'),
#  ('38', '95', 5.0, '892430094'),
# ...

# %%
trainset, testset = train_test_split(data_set, test_size=.15)

# %%
algo=KNNWithMeans(k=50,sim_options={'name':'pearson_baseline','user_based':True})
algo.sim_options
# Out:
# {'name': 'pearson_baseline', 'user_based': True}

# %%
algo.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
algo.predict(iid=196,uid=242,verbose=True)
# Out:
# user: 242        item: 196        r_ui = None   est = 3.53   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}
# Prediction(uid=242, iid=196, r_ui=None, est=3.5315882352941177, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'})

# %%
y_pred=algo.test(testset)

# %%
y_pred
# Out:
# [Prediction(uid='379', iid='7', r_ui=5.0, est=4.231658944097244, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='405', iid='732', r_ui=5.0, est=2.1270979052041246, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='833', iid='52', r_ui=3.0, est=3.4760707017021297, details={'actual_k': 37, 'was_impossible': False}),
#  Prediction(uid='233', iid='478', r_ui=5.0, est=4.80665603094982, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid='773', iid='1097', r_ui=4.0, est=2.9480085489724157, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='711', iid='170', r_ui=5.0, est=4.623564107270033, details={'actual_k': 50, 'was_impossible': False}),
#  Prediction(uid='393', iid='136', r_ui=5.0, est=3.7447026163316983, details={'actual_k': 38, 'was_impossible': False}),
#  Prediction(uid='303', iid='636', r_ui=3.0, est=3.2655334961497955, details={'actual_k': 41, 'was_impossible': False}),
# ...

# %%
accuracy.rmse(y_pred)
# Out:
# RMSE: 0.9187
# 0.9187383633963555
